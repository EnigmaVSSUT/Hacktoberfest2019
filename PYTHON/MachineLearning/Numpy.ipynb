# %%
import numpy as np
a= np.ones(3)
a
# Out:
# array([1., 1., 1.])

# %%
type(z)
# Out:
# numpy.ndarray

# %%
np.random.seed(0)
z1= np.random.randint(19,size=6)
z1
# Out:
# array([12, 15,  0,  3,  3,  7])

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4f284832-c580-478e-89a5-bb2a3bb72358" name="files[]" multiple disabled />
#      <output id="result-4f284832-c580-478e-89a5-bb2a3bb72358">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 4k-thor-in-avengers-endgame-7p.jpg to 4k-thor-in-avengers-endgame-7p.jpg

# %%
from skimage import io
pic = io.imread('4k-thor-in-avengers-endgame-7p.jpg')
pic.shape
# Out:
# (339, 602, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(pic)

# %%
picin = np.sin(pic)
picin
# Out:
# Array([[[-0.5366 , -0.9614 ,  0.8364 ],
#         [-0.5366 , -0.9614 ,  0.8364 ],
#         [-0.2793 ,  0.9907 , -0.9614 ],
#         ...,
#         [ 0.412  , -0.9614 ,  0.1499 ],
#         [-0.757  , -0.5366 ,  0.6504 ],
#         [-0.2793 ,  0.9907 , -0.9614 ]],
#
#        [[-0.544  ,  0.6504 ,  0.1499 ],
#         [-1.     , -0.2878 ,  0.913  ],
#         [ 0.9893 ,  0.4202 , -0.9614 ],
#         ...,
#         [-0.959  ,  0.4202 ,  0.6504 ],
#         [-0.2793 ,  0.9907 , -0.9614 ],
#         [ 0.9893 ,  0.4202 , -0.9614 ]],
#
#        [[-0.544  ,  0.6504 ,  0.1499 ],
#         [-1.     , -0.2878 ,  0.913  ],
#         [ 0.412  ,  0.9907 , -0.751  ],
#         ...,
#         [ 0.657  ,  0.6504 , -0.751  ],
#         [ 0.9893 ,  0.4202 , -0.9614 ],
#         [ 0.412  ,  0.9907 , -0.751  ]],
#
#        ...,
#
#        [[ 0.4363 , -0.4756 ,  0.9976 ],
#         [ 0.6704 , -0.7026 , -0.602  ],
#         [-0.768  ,  0.796  ,  0.3467 ],
#         ...,
# ...

# %%
z= np.array([1,2,3,4,5])
z>3

z1= np.array([1,2,3,4,4,3,4,5])
z1[z1>2]
# Out:
# array([3, 4, 4, 3, 4, 5])

# %%
photomsk = np.where(pic> 100, 200, 0)
plt.imshow(photomsk)

# %%
plt.imshow(photomsk[::-1, ::])
